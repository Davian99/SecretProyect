# %%
import string
from collections import defaultdict
import database
import time
import queue
import threading

from houses.Retabet import Retabet
from houses.Bwin import Bwin
from houses.WilliamHill import WilliamHill

from bet import Bet

def houses_exec(q, house):
    for sport in house.sports:
            house.sport_bets(sport)
            for match in house.ret_bets[sport]:
                if match.is_error():
                    continue
                q.put(match)
                
                
def retorno(ca, cb):
    return ca / (1 + (ca / cb))

reta = Retabet()
bwin = Bwin()
william_hill = WilliamHill()
house_list = [reta, bwin, william_hill]

while True:
    match_dict = defaultdict(lambda: [])
    
    threads = []
    q = queue.Queue()
    for house in house_list:
        t = threading.Thread(target=houses_exec, args=(q, house,))
        threads.append(t)
        t.start()
        
    for t in threads:
        t.join()
    
    for match in q.queue:
        match_dict[match.hash()].append(match)
    
    retornos = []
    luck = False
    cnt = 0
    for key, match in match_dict.items():
        if len(match) <= 1:
            continue
        cnt += 1
        for m1 in match:
            for m2 in match:
                ret = retorno(m1.bets[0], m2.bets[1])
                retornos.append((ret, m1, m2))
                if ret >= 1:
                    print(ret)
                    print(m1, m2)
                    luck = True
    retornos.sort(key=lambda x: x[0], reverse=True)
    if len(retornos) and not luck:
        print(f"No luck: {retornos[0][0], cnt}")
    time.sleep(5)
#retornos.sort(key=lambda x: x[0], reverse=True)
#for r in retornos[:10]:
#    print(f"{r[0]}: {r[1], r[2]}")
# Out:
# Retabet done in 1.82
# WilliamHill done in 5.49
# Bwin done in 7.46
# WilliamHill done in 3.16
# Bwin done in 3.16
# 1.26
# DMITRI RAZINKOV (1.8) x IVAN SOLDATOV (1.91) DMITRI RAZINKOV (1.19) x IVAN SOLDATOV (4.2)
# 1.1571189279731993
# ALEKSANDR FEDOROV (4.4) x SERGEY KUZMIN (1.17) ALEKSANDR FEDOROV (2.3) x SERGEY KUZMIN (1.57)
# 1.2166380789022297
# ALEKSANDR FEDOROV (4.1) x VLADIMIR SAFONOV (1.2) ALEKSANDR FEDOROV (2.0) x VLADIMIR SAFONOV (1.73)
# 1.2116838487972508
# ALEKSANDR FEDOROV (4.1) x VLADIMIR SAFONOV (1.2) ALEKSANDR FEDOROV (2.0) x VLADIMIR SAFONOV (1.72)
# Retabet done in 0.70
# Bwin done in 2.14
# WilliamHill done in 2.41
# WilliamHill done in 1.38
# Bwin done in 2.45
# 1.2714518760195759
# DMITRI RAZINKOV (1.8) x IVAN SOLDATOV (1.91) DMITRI RAZINKOV (1.18) x IVAN SOLDATOV (4.33)
# 1.1571189279731993
# ALEKSANDR FEDOROV (4.4) x SERGEY KUZMIN (1.17) ALEKSANDR FEDOROV (2.3) x SERGEY KUZMIN (1.57)
# 1.2166380789022297
# ALEKSANDR FEDOROV (4.1) x VLADIMIR SAFONOV (1.2) ALEKSANDR FEDOROV (2.0) x VLADIMIR SAFONOV (1.73)
# 1.2116838487972508
# ALEKSANDR FEDOROV (4.1) x VLADIMIR SAFONOV (1.2) ALEKSANDR FEDOROV (2.0) x VLADIMIR SAFONOV (1.72)
# Retabet done in 0.81
# WilliamHill done in 2.00
# Bwin done in 2.21
# WilliamHill done in 1.33
# Bwin done in 2.14
# 1.2714518760195759
# DMITRI RAZINKOV (1.8) x IVAN SOLDATOV (1.91) DMITRI RAZINKOV (1.18) x IVAN SOLDATOV (4.33)
# 1.1571189279731993
# ALEKSANDR FEDOROV (4.4) x SERGEY KUZMIN (1.17) ALEKSANDR FEDOROV (2.3) x SERGEY KUZMIN (1.57)
# 1.2166380789022297
# ALEKSANDR FEDOROV (4.1) x VLADIMIR SAFONOV (1.2) ALEKSANDR FEDOROV (2.0) x VLADIMIR SAFONOV (1.73)
# 1.2116838487972508
# ALEKSANDR FEDOROV (4.1) x VLADIMIR SAFONOV (1.2) ALEKSANDR FEDOROV (2.0) x VLADIMIR SAFONOV (1.72)
# Retabet done in 0.71
# WilliamHill done in 1.98
# Bwin done in 2.14
# WilliamHill done in 1.33
# Bwin done in 2.23
# 1.2413793103448276
# DMITRI RAZINKOV (1.8) x IVAN SOLDATOV (1.91) DMITRI RAZINKOV (1.2) x IVAN SOLDATOV (4.0)
# 1.1571189279731993
# ALEKSANDR FEDOROV (4.4) x SERGEY KUZMIN (1.17) ALEKSANDR FEDOROV (2.3) x SERGEY KUZMIN (1.57)
# 1.2166380789022297
# ALEKSANDR FEDOROV (4.1) x VLADIMIR SAFONOV (1.2) ALEKSANDR FEDOROV (2.0) x VLADIMIR SAFONOV (1.73)
# 1.2116838487972508
# ALEKSANDR FEDOROV (4.1) x VLADIMIR SAFONOV (1.2) ALEKSANDR FEDOROV (2.0) x VLADIMIR SAFONOV (1.72)
# Retabet done in 0.72
# WilliamHill done in 2.06
# Bwin done in 2.25
# WilliamHill done in 1.36
# Bwin done in 2.10
# 1.2413793103448276
# DMITRI RAZINKOV (1.8) x IVAN SOLDATOV (1.91) DMITRI RAZINKOV (1.2) x IVAN SOLDATOV (4.0)
# 1.1571189279731993
# ALEKSANDR FEDOROV (4.4) x SERGEY KUZMIN (1.17) ALEKSANDR FEDOROV (2.3) x SERGEY KUZMIN (1.57)
# 1.2166380789022297
# ALEKSANDR FEDOROV (4.1) x VLADIMIR SAFONOV (1.2) ALEKSANDR FEDOROV (2.0) x VLADIMIR SAFONOV (1.73)
# 1.2116838487972508
# ALEKSANDR FEDOROV (4.1) x VLADIMIR SAFONOV (1.2) ALEKSANDR FEDOROV (2.0) x VLADIMIR SAFONOV (1.72)
# Retabet done in 0.64
# WilliamHill done in 1.91
# Bwin done in 2.36
# WilliamHill done in 1.58
# Bwin done in 2.17
# 1.2413793103448276
# DMITRI RAZINKOV (1.8) x IVAN SOLDATOV (1.91) DMITRI RAZINKOV (1.2) x IVAN SOLDATOV (4.0)
# 1.1571189279731993
# ALEKSANDR FEDOROV (4.4) x SERGEY KUZMIN (1.17) ALEKSANDR FEDOROV (2.3) x SERGEY KUZMIN (1.57)
# 1.2166380789022297
# ALEKSANDR FEDOROV (4.1) x VLADIMIR SAFONOV (1.2) ALEKSANDR FEDOROV (2.0) x VLADIMIR SAFONOV (1.73)
# 1.2116838487972508
# ALEKSANDR FEDOROV (4.1) x VLADIMIR SAFONOV (1.2) ALEKSANDR FEDOROV (2.0) x VLADIMIR SAFONOV (1.72)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-f39929a234d8> in <module>
#      63     if len(retornos) and not luck:
#      64         print(f"No luck: {retornos[0][0], cnt}")
# ---> 65     time.sleep(5)
#      66 #retornos.sort(key=lambda x: x[0], reverse=True)
#      67 #for r in retornos[:10]:
#
# KeyboardInterrupt:
